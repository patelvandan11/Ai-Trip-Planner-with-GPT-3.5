# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Expanded_Indian_Travel_Dataset.csv')

# %%
data
# Out:
#             Destination Name          State Region   Category  \
# 0                  Taj Mahal  Uttar Pradesh  North   Heritage
# 1                     Jaipur      Rajasthan   West   Heritage
# 2                        Goa            Goa   West      Beach
# 3          Kerala Backwaters         Kerala  South     Nature
# 4                   Varanasi  Uttar Pradesh  North  Religious
# ..                       ...            ...    ...        ...
# 105                  Udaipur      Rajasthan   West   Heritage
# 106               Darjeeling    West Bengal   East     Nature
# 107                   Munnar         Kerala  South     Nature
# 108  Ajanta and Ellora Caves    Maharashtra   West   Heritage
# 109              Cherrapunji      Meghalaya   East     Nature
#
#     Popular Attraction Accessibility       Nearest Airport  \
# 0            Taj Mahal          Easy    Agra Civil Enclave
# 1           Amber Fort          Easy  Jaipur International
# ...

# %%
data.shape
# Out:
# (110, 8)
